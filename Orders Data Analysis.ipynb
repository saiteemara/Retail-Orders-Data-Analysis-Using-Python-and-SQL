# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.8.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: black>=24.10.0 in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (6.2.0)
# Collecting kagglesdk<1.0,>=0.1.14 (from kaggle)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Downloading mypy-1.19.1-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (24.2)
# Requirement already satisfied: protobuf in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: six>=1.10 in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (4.67.1)
# Collecting types-requests (from kaggle)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\sai\anaconda3\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\sai\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\sai\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\sai\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\sai\anaconda3\lib\site-packages (from black>=24.10.0->kaggle) (4.3.7)
# Requirement already satisfied: colorama in c:\users\sai\anaconda3\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\sai\anaconda3\lib\site-packages (from mypy>=1.15.0->kaggle) (4.12.2)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Downloading librt-0.7.8-cp313-cp313-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: webencodings in c:\users\sai\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\sai\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sai\anaconda3\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sai\anaconda3\lib\site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sai\anaconda3\lib\site-packages (from requests->kaggle) (2025.6.15)
# Downloading kaggle-1.8.3-py3-none-any.whl (102 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Downloading mypy-1.19.1-cp313-cp313-win_amd64.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.1 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/10.1 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/10.1 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/10.1 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/10.1 MB 580.9 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.3/10.1 MB 624.4 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.3/10.1 MB 624.4 kB/s eta 0:00:15
#    ------ --------------------------------- 1.6/10.1 MB 640.5 kB/s eta 0:00:14
#    ------- -------------------------------- 1.8/10.1 MB 680.2 kB/s eta 0:00:13
#    ------- -------------------------------- 1.8/10.1 MB 680.2 kB/s eta 0:00:13
#    -------- ------------------------------- 2.1/10.1 MB 693.8 kB/s eta 0:00:12
#    --------- ------------------------------ 2.4/10.1 MB 696.2 kB/s eta 0:00:12
#    --------- ------------------------------ 2.4/10.1 MB 696.2 kB/s eta 0:00:12
#    ---------- ----------------------------- 2.6/10.1 MB 700.4 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.6/10.1 MB 700.4 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.6/10.1 MB 700.4 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.6/10.1 MB 700.4 kB/s eta 0:00:11
#    ----------- ---------------------------- 2.9/10.1 MB 633.0 kB/s eta 0:00:12
#    ----------- ---------------------------- 2.9/10.1 MB 633.0 kB/s eta 0:00:12
#    ----------- ---------------------------- 2.9/10.1 MB 633.0 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/10.1 MB 596.6 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/10.1 MB 596.6 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/10.1 MB 596.6 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/10.1 MB 596.6 kB/s eta 0:00:12
#    ------------- -------------------------- 3.4/10.1 MB 552.6 kB/s eta 0:00:13
#    ------------- -------------------------- 3.4/10.1 MB 552.6 kB/s eta 0:00:13
#    ------------- -------------------------- 3.4/10.1 MB 552.6 kB/s eta 0:00:13
#    -------------- ------------------------- 3.7/10.1 MB 539.9 kB/s eta 0:00:12
#    --------------- ------------------------ 3.9/10.1 MB 558.1 kB/s eta 0:00:12
#    ----------------- ---------------------- 4.5/10.1 MB 606.5 kB/s eta 0:00:10
#    ------------------ --------------------- 4.7/10.1 MB 628.1 kB/s eta 0:00:09
#    ------------------- -------------------- 5.0/10.1 MB 647.9 kB/s eta 0:00:08
#    --------------------- ------------------ 5.5/10.1 MB 693.5 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.8/10.1 MB 715.1 kB/s eta 0:00:07
#    ----------------------- ---------------- 6.0/10.1 MB 732.8 kB/s eta 0:00:06
#    ------------------------- -------------- 6.6/10.1 MB 769.0 kB/s eta 0:00:05
#    --------------------------- ------------ 7.1/10.1 MB 808.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.3/10.1 MB 821.0 kB/s eta 0:00:04
#    ------------------------------ --------- 7.6/10.1 MB 836.3 kB/s eta 0:00:04
#    -------------------------------- ------- 8.1/10.1 MB 867.9 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.7/10.1 MB 899.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 907.8 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.1 MB 917.2 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.1 MB 928.6 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 939.6 kB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 945.7 kB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 945.2 kB/s eta 0:00:00
# Downloading librt-0.7.8-cp313-cp313-win_amd64.whl (50 kB)
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Installing collected packages: types-requests, librt, types-tqdm, mypy, kagglesdk, kaggle
#
#    ------------- -------------------------- 2/6 [types-tqdm]
#   Attempting uninstall: mypy
#    ------------- -------------------------- 2/6 [types-tqdm]
#     Found existing installation: mypy 1.14.1
#    ------------- -------------------------- 2/6 [types-tqdm]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#     Uninstalling mypy-1.14.1:
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#       Successfully uninstalled mypy-1.14.1
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------- ------------------- 3/6 [mypy]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    -------------------------- ------------- 4/6 [kagglesdk]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    ---------------------------------------- 6/6 [kaggle]
#
# Successfully installed kaggle-1.8.3 kagglesdk-0.1.15 librt-0.7.8 mypy-1.19.1 types-requests-2.32.4.20260107 types-tqdm-4.67.0.20250809

# %%
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# Downloading orders.csv.zip to C:\Users\Sai\OneDrive\Desktop\Projects
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:01<00:00, 191kB/s]
# 100%|##########| 200k/200k [00:01<00:00, 191kB/s]

# %%
#extract file from zip file
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip') 
zip_ref.extractall() # extract file to dir
zip_ref.close() # close file

# %%
#read data from the file and handle null values
import pandas as pd
df = pd.read_csv("orders.csv")
df.head(10)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
# 5         6  2022-03-13   Not Available   Consumer  United States
# 6         7  2022-12-28  Standard Class   Consumer  United States
# 7         8  2022-01-25  Standard Class   Consumer  United States
# 8         9  2023-03-23   Not Available   Consumer  United States
# 9        10  2023-05-16  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
# 5      Los Angeles  California        90032   West        Furniture
# 6      Los Angeles  California        90032   West  Office Supplies
# 7      Los Angeles  California        90032   West       Technology
# 8      Los Angeles  California        90032   West  Office Supplies
# 9      Los Angeles  California        90032   West  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# 1       Chairs  FUR-CH-10000454         600         730         3
# 2       Labels  OFF-LA-10000240          10          10         2
# 3       Tables  FUR-TA-10000577         780         960         5
# 4      Storage  OFF-ST-10000760          20          20         2
# 5  Furnishings  FUR-FU-10001487          50          50         7
# 6          Art  OFF-AR-10002833          10          10         4
# 7       Phones  TEC-PH-10002275         860         910         6
# 8      Binders  OFF-BI-10003910          20          20         3
# 9   Appliances  OFF-AP-10002892          90         110         5
#
#    Discount Percent
# 0                 2
# 1                 3
# 2                 5
# 3                 2
# 4                 5
# 5                 3
# 6                 3
# 7                 5
# 8                 2
# 9                 3

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
df = pd.read_csv("orders.csv",na_values=["Not Available","unknown"])

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#rename columns names ..make them lower case and replace space with underscore
df.columns = df.columns.str.lower().str.replace(" ","_")

# %%
df.head(2)
# Out:
#    order_id  order_date     ship_mode   segment        country       city  \
# 0         1  2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2  2023-08-15  Second Class  Consumer  United States  Henderson
#
#       state  postal_code region   category sub_category       product_id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost_price  list_price  quantity  discount_percent
# 0         240         260         2                 2
# 1         600         730         3                 3

# %%
#derive new columns discount , sale price and profit
df["discount"] = df["list_price"] * df["discount_percent"] * .01

# %%
df["sale_price"] = df["list_price"] - df["discount"]

# %%
df["profit"] = df["sale_price"] - df["cost_price"]

# %%
df.head(2)
# Out:
#    order_id  order_date     ship_mode   segment        country       city  \
# 0         1  2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2  2023-08-15  Second Class  Consumer  United States  Henderson
#
#       state  postal_code region   category sub_category       product_id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost_price  list_price  quantity  discount_percent  discount  sale_price  \
# 0         240         260         2                 2       5.2       254.8
# 1         600         730         3                 3      21.9       708.1
#
#    profit
# 0    14.8
# 1   108.1

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sale_price          float64
# profit              float64
# dtype: object

# %%
#convert order date from object data type to datetime
df['order_date']=pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
#drop cost price,list price and discount percent columns
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %%
df.head(2)
# Out:
#    order_id order_date     ship_mode   segment        country       city  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       state  postal_code region   category sub_category       product_id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    quantity  discount  sale_price  profit
# 0         2       5.2       254.8    14.8
# 1         3      21.9       708.1   108.1

# %%
pip install pandas mysql-connector-python sqlalchemy
# Out:
# Requirement already satisfied: pandas in c:\users\sai\anaconda3\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: sqlalchemy in c:\users\sai\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sai\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sai\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sai\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sai\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sai\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sai\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\sai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading mysql_connector_python-9.5.0-cp313-cp313-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/16.5 MB 9.5 MB/s eta 0:00:02
#    -------- ------------------------------- 3.7/16.5 MB 9.2 MB/s eta 0:00:02
#    -------------- ------------------------- 6.0/16.5 MB 9.9 MB/s eta 0:00:02
#    -------------------- ------------------- 8.4/16.5 MB 10.1 MB/s eta 0:00:01
#    -------------------------- ------------- 11.0/16.5 MB 10.5 MB/s eta 0:00:01
#    --------------------------------- ------ 13.6/16.5 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------- -- 15.5/16.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.5 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0

# %%
from sqlalchemy import create_engine

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
engine = sal.create_engine('mysql+mysqlconnector://root:teemara456@localhost:3306/mydatabase')
conn=engine.connect()

# %%
#load the data into sql server using append option
df.to_sql('orders', con=conn , index=False, if_exists = 'append')
# Out:
# 9994
